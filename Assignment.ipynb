# %% [markdown]
# # __My Jupyter Notebook on IBM Watson Studio__

# %% [markdown]
# **GANESH MAHARAJ**
# Data Scientist

# %% [markdown]
# *i'm intrested in data science because i really love to get insights after processing data, which are valuble for a company or an organisation to improve*
# *I love to contribute to automation industry with the help of data science*

# %% [markdown]
# ### My code supposed to print Hello World!:

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ***

# %% [markdown]
# - one
# - two
# - three

# %% [markdown]
# 1. one
# 2. two
# 3. three

# %% [markdown]
# ~strikethrough~
